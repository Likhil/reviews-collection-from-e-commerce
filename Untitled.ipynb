# %%
import requests 
from bs4 import BeautifulSoup

# %%
URL = "https://drive.google.com/drive/folders/1PEJZur082d2oLp9ZWaBfp1sj5WIlVBRI"
r = requests.get(URL) 
  
soup = BeautifulSoup(r.content) 
print(soup.prettify()) 

table = soup.find('div', attrs = {'class':'WYuW0e RDfNAe GZwC2b dPmH0b'}) 
  
print(table)
# Out:
# <!DOCTYPE html>
# <html class="a-nEbBXb a-Ra-Qc a-dkl3Ye" dir="ltr" lang="en">
#  <head>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta name="google" value="notranslate"/>
#   <meta content="width=1000, user-scalable=no" name="viewport"/>
#   <title>
#    DOH COVID-19 Data Drop (05/20) - Google Drive
#   </title>
#   <script>
#    (function(){(function(){function e(g){this.t={};this.tick=function(h,k,f){var l=void 0!=f?f:(new Date).getTime();this.t[h]=[l,k];if(void 0==f)try{window.console.timeStamp("CSI/"+h)}catch(n){}};this.tick("start",null,g)}var a;if(window.performance)var d=(a=window.performance.timing)&&a.responseStart;var m=0<d?new e(d):new e;window.jstiming={Timer:e,load:m};if(a){var b=a.navigationStart;0<b&&d>=b&&(window.jstiming.srt=d-b)}if(a){var c=window.jstiming.load;0<b&&d>=b&&(c.tick("_wtsrt",void 0,b),c.tick("wtsrt_","_wtsrt",
# ...
